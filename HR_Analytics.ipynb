# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('/content/employees-1.zip')

# %%
df=pd.DataFrame(data)
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
#To find the number of duplicates in the dataset

df.duplicated().sum()
# Out:
# np.int64(3008)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      11991 non-null  float64
#  1   lastEvaluation         11991 non-null  float64
#  2   numberOfProjects       11991 non-null  int64
#  3   avgMonthlyHours        11991 non-null  int64
#  4   timeSpent.company      11991 non-null  int64
#  5   workAccident           11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotionInLast5years  11991 non-null  int64
#  8   dept                   11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       11991.000000    11991.000000      11991.000000     11991.000000
# mean            0.629658        0.716683          3.802852       200.473522
# std             0.241070        0.168343          1.163238        48.727813
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.480000        0.570000          3.000000       157.000000
# 50%             0.660000        0.720000          4.000000       200.000000
# 75%             0.820000        0.860000          5.000000       243.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       11991.000000  11991.000000  11991.000000           11991.000000
# mean            3.364857      0.154282      0.166041               0.016929
# ...

# %%
df['left'].value_counts()
# Out:
# left
# 0    10000
# 1     1991
# Name: count, dtype: int64

# %%
plt.pie(df['left'].value_counts(),labels=df['left'].value_counts())
plt.show()

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
df['numberOfProjects'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3])

# %% [markdown]
# **Count Plot & Histogram** *italicized text*

# %%
x=np.random.randint(1,100,30)
ser=pd.Series(x)

# %%
sns.countplot(data=ser)
# Out:
# <Axes: ylabel='count'>

# %%
sns.histplot(data=ser)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.countplot(data=df,x='numberOfProjects',hue='left')
# Out:
# <Axes: xlabel='numberOfProjects', ylabel='count'>

# %%
df['avgMonthlyHours']
# Out:
# 0        157
# 1        262
# 2        272
# 3        159
# 4        153
#         ...
# 14992    245
# 14995    274
# 14996    175
# 14997    177
# 14998    271
# Name: avgMonthlyHours, Length: 11991, dtype: int64

# %%
sns.histplot(data=df,x='avgMonthlyHours',hue='left')
plt.show()

# %%
df[df['avgMonthlyHours']<120]['salary'].value_counts()
# Out:
# salary
# low       160
# medium    141
# high       41
# Name: count, dtype: int64

# %%
df[df['avgMonthlyHours']>280]['salary'].value_counts()
# Out:
# salary
# low       196
# medium    128
# high       19
# Name: count, dtype: int64

# %%
df['timeSpent.company'].unique()
# Out:
# array([ 3,  6,  4,  5,  2,  8, 10,  7])

# %%
sns.countplot(data=df,x='timeSpent.company',hue='left')
# Out:
# <Axes: xlabel='timeSpent.company', ylabel='count'>

# %%
df[ 'dept'].value_counts()
# Out:
# dept
# sales          3239
# technical      2244
# support        1821
# IT              976
# RandD           694
# product_mng     686
# marketing       673
# accounting      621
# hr              601
# management      436
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='dept',hue='left')
plt.xticks(rotation=75)
plt.show()

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
#dept == sales
x=df[(df['dept']=='sales') &( df['left']==1)]['dept'].value_counts()
y=df[(df['dept']=='sales') &( df['left']==0)]['dept'].value_counts()

attrition=(x/(x+y))*100
attrition
# Out:
# dept
# sales    16.98055
# Name: count, dtype: float64

# %%
#dept == technical
x=df[(df['dept']=='technical') &( df['left']==1)]['dept'].value_counts()
y=df[(df['dept']=='technical') &( df['left']==0)]['dept'].value_counts()
attrition=(x/(x+y))*100
attrition
# Out:
# dept
# technical    17.379679
# Name: count, dtype: float64

# %%
#dept == support
x=df[(df['dept']=='support') &( df['left']==1)]['dept'].value_counts()
y=df[(df['dept']=='support') &( df['left']==0)]['dept'].value_counts()
attrition=(x/(x+y))*100
attrition
# Out:
# dept
# support    17.133443
# Name: count, dtype: float64

# %%
df['salary'].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %%
plt.pie(df['salary'].value_counts(),labels=df['salary'].value_counts().keys(),autopct='%.2f%%')
plt.show()

# %%
sns.countplot(data=df,x='salary',hue='left')
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
df.corr(numeric_only=True)['left'].sort_values()[:-1]
# Out:
# satisfactoryLevel       -0.350558
# workAccident            -0.125436
# promotionInLast5years   -0.044657
# lastEvaluation           0.013520
# numberOfProjects         0.030928
# avgMonthlyHours          0.070409
# timeSpent.company        0.173295
# Name: left, dtype: float64

# %%
df['satisfactoryLevel']
# Out:
# 0        0.38
# 1        0.80
# 2        0.11
# 3        0.37
# 4        0.41
#          ...
# 14992    0.30
# 14995    0.99
# 14996    0.72
# 14997    0.24
# 14998    0.77
# Name: satisfactoryLevel, Length: 11991, dtype: float64

# %%
sns.histplot(data=df,x='satisfactoryLevel',hue='left')
# Out:
# <Axes: xlabel='satisfactoryLevel', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
df['lastEvaluation']
# Out:
# 0        0.53
# 1        0.86
# 2        0.88
# 3        0.52
# 4        0.50
#          ...
# 14992    0.88
# 14995    0.83
# 14996    0.72
# 14997    0.91
# 14998    0.83
# Name: lastEvaluation, Length: 11991, dtype: float64

# %%
sns.histplot(data=df,x='lastEvaluation',hue='left')
# Out:
# <Axes: xlabel='lastEvaluation', ylabel='Count'>

# %%
df['workAccident']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 14992    0
# 14995    0
# 14996    0
# 14997    0
# 14998    0
# Name: workAccident, Length: 11991, dtype: int64

# %%
sns.countplot(data=df,x='workAccident',hue='left')
# Out:
# <Axes: xlabel='workAccident', ylabel='count'>

# %%
df['promotionInLast5years'].value_counts()
# Out:
# promotionInLast5years
# 0    11788
# 1      203
# Name: count, dtype: int64

# %%
df['salary'].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %%
df[df['satisfactoryLevel']>(df['satisfactoryLevel'].mean())]['satisfactoryLevel'].groupby(df['salary']).count()
# Out:
# salary
# high       561
# low       3112
# medium    2930
# Name: satisfactoryLevel, dtype: int64

# %%
df[df['satisfactoryLevel']>(df['satisfactoryLevel'].mean())]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 1                   0.80            0.86                 5              262
# 6                   0.92            0.85                 5              259
# 13                  0.78            0.99                 4              255
# 14                  0.76            0.89                 5              262
# 19                  0.89            0.92                 5              242
# ...                  ...             ...               ...              ...
# 14990               0.73            0.52                 3              274
# 14991               0.85            0.53                 3              250
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df['satisfactoryLevel'].mean()
# Out:
# np.float64(0.6296580768910016)
